# %%
import pandas as pd
import numpy as np
np.random.seed(0)
data = {
'Roll No': range(1, 51),
'Name': ['Student ' + str(i) for i in range(1, 51)],
'Subject1': np.random.randint(50, 100, size=50),
'Subject2': np.random.randint(50, 100, size=50),
'Subject3': np.random.randint(50, 100, size=50),
'Subject4': np.random.randint(50, 100, size=50),
'Subject5': np.random.randint(50, 100, size=50)
}
df = pd.DataFrame(data)
df.head()
# Out:
#    Roll No       Name  Subject1  Subject2  Subject3  Subject4  Subject5
# 0        1  Student 1        94        61        55        69        74
# 1        2  Student 2        97        78        91        96        65
# 2        3  Student 3        50        84        85        92        91
# 3        4  Student 4        53        50        50        90        68
# 4        5  Student 5        53        50        81        63        90

# %%
df.mean(numeric_only=True)
# Out:
# Roll No     25.50
# Subject1    72.24
# Subject2    72.76
# Subject3    74.02
# Subject4    73.66
# Subject5    75.74
# dtype: float64

# %%
df.describe()
# Out:
#         Roll No   Subject1   Subject2   Subject3   Subject4   Subject5
# count  50.00000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   25.50000  72.240000  72.760000  74.020000  73.660000  75.740000
# std    14.57738  14.028484  15.593772  15.858417  14.206365  14.114416
# min     1.00000  50.000000  50.000000  50.000000  52.000000  51.000000
# 25%    13.25000  60.500000  61.000000  60.000000  63.000000  65.000000
# 50%    25.50000  72.000000  70.000000  78.000000  73.000000  74.500000
# 75%    37.75000  84.250000  87.500000  86.000000  83.750000  88.750000
# max    50.00000  99.000000  99.000000  99.000000  98.000000  97.000000

# %%
df.mode().head(1)
# Out:
#    Roll No       Name  Subject1  Subject2  Subject3  Subject4  Subject5
# 0        1  Student 1      74.0      50.0      50.0      63.0      53.0

# %%
import pandas as pd

data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}

df = pd.DataFrame(data)

df = df.rename(columns={'B': 'NewColumn'})
print(df)
# Out:
#    A  NewColumn  C
# 0  1          4  7
# 1  2          5  8
# 2  3          6  9

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'A': [1, 2, 2, 3, 4, 4],
    'B': ['apple', 'banana', 'apple', 'banana', 'banana', 'banana'],
    'C': [10.5, 8.2, 8.2, 6.7, 8.2, 8.2]
}

df = pd.DataFrame(data)

# Check for duplicate rows
is_duplicate = df.duplicated()

# Print the boolean Series indicating duplicate rows
print(is_duplicate)
df[~is_duplicate]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool
#    A       B     C
# 0  1   apple  10.5
# 1  2  banana   8.2
# 2  2   apple   8.2
# 3  3  banana   6.7
# 4  4  banana   8.2

# %%
# Create a DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Set an existing column as the index
df_with_custom_index = df.set_index('A')

# Print the DataFrame with custom index
print(df_with_custom_index)
# Out:
#    B
# A
# 1  4
# 2  5
# 3  6

# %%
df1 = df[['A', 'B']]
df2 = df[['C', 'C']]
# df2.set_index(['a', 'b', 'c', 'd', 'e', 'f'])
df1.join(df2, how="right")
# Out:
#    A       B     C     C
# 0  1   apple  10.5  10.5
# 1  2  banana   8.2   8.2
# 2  2   apple   8.2   8.2
# 3  3  banana   6.7   6.7
# 4  4  banana   8.2   8.2
# 5  4  banana   8.2   8.2

# %%
df1 = df[['A', 'B']]
df2 = df['C']
df1.join(df2, how="right")
# Out:
#    A       B     C
# 0  1   apple  10.5
# 1  2  banana   8.2
# 2  2   apple   8.2
# 3  3  banana   6.7
# 4  4  banana   8.2
# 5  4  banana   8.2

# %%
pd.concat([df[['A', 'B']], df['B']], axis=1)
# Out:
#    A       B       B
# 0  1   apple   apple
# 1  2  banana  banana
# 2  2   apple   apple
# 3  3  banana  banana
# 4  4  banana  banana
# 5  4  banana  banana

# %%
df = df.rename(columns={'B': "MRBRUH"})
df.transpose()
df.plot()
# Out:
# <AxesSubplot: >

# %%
"""
Splitting Horizontally: df.iloc[:df.shape[0]-0]
Splitting Vertically: df.loc[]
delete Row: df.drop(1)
"""
# Out:
# '\nSplitting Horizontally: df.iloc[:df.shape[0]-0]\nSplitting Vertically: df.loc[]\n'

# %%
from sklearn.cluster import KMeans
help(KMeans)
# Out:
# Help on class KMeans in module sklearn.cluster._kmeans:
#
# class KMeans(_BaseKMeans)
#  |  KMeans(n_clusters=8, *, init='k-means++', n_init='warn', max_iter=300, tol=0.0001, verbose=0, random_state=None, copy_x=True, algorithm='lloyd')
#  |
#  |  K-Means clustering.
#  |
#  |  Read more in the :ref:`User Guide <k_means>`.
#  |
#  |  Parameters
#  |  ----------
#  |
#  |  n_clusters : int, default=8
#  |      The number of clusters to form as well as the number of
#  |      centroids to generate.
#  |
#  |  init : {'k-means++', 'random'}, callable or array-like of shape             (n_clusters, n_features), default='k-means++'
#  |      Method for initialization:
#  |
#  |      'k-means++' : selects initial cluster centroids using sampling based on
#  |      an empirical probability distribution of the points' contribution to the
#  |      overall inertia. This technique speeds up convergence. The algorithm
# ...

# %%
kmeans = KMeans(n_clusters=1, n_init="auto")
kmeans.fit(df)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_
labels
# Out:
# array([0, 0, 0])

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the random seed for reproducibility
np.random.seed(42)

# Generate random data
num_samples = 100
num_features = 2
data = np.random.randn(num_samples, num_features)

kmeans = KMeans(n_clusters=num_features, n_init="auto")
kmeans.fit(data)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Print the generated data
plt.scatter(data[:, 0], data[:, 1], c=labels)

# %%
import seaborn as sns

# Generate random data
data = [1, 2, 2, 3, 3, 3, 4, 4, 5, 5, 5, 5]

# Plot histogram using Seaborn
sns.distplot(data, kde=False, bins=5)

# Display the plot
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()
# Out:
# C:\Users\medal\AppData\Local\Temp\ipykernel_7532\1556627102.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data, kde=False, bins=5)

# %%
import matplotlib.pyplot as plt

# Generate random data
data = [30, 20, 15, 35]

# Labels for the pie chart
labels = ['Category 1', 'Category 2', 'Category 3', 'Category 4']

# Create a pie chart
plt.pie(data, autopct='%1.1f%%')

# Set aspect ratio to be equal so that pie is drawn as a circle
plt.axis('equal')

# Set a title for the pie chart
plt.title('Pie Chart')

# Display the pie chart
plt.show()
